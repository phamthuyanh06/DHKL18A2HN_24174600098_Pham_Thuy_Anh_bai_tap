# %%
import xml.dom.minidom 
 
def main(): 
    #Sử dụng hàm parse() để đọc và phân tích file "employee.xml sau đó chuyển     
          # đổi nó nó thành biến đối tượng 'doc'. 
    doc=xml.dom.minidom.parse("employee.xml"); 
 
    #In ra In ra tên của node gốc và tag name của node đầu tiên  trong file .xml 
    print(doc.nodeName) 
    print(doc.firstChild.tagName) 
if __name__=="__main__": 
    main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 12
#      10     print(doc.firstChild.tagName)
#      11 if __name__=="__main__":
# ---> 12     main()
#
# Cell In[3], line 6, in main()
#       3 def main():
#       4     #Sử dụng hàm parse() để đọc và phân tích file "employee.xml sau đó chuyển
#       5           # đổi nó nó thành biến đối tượng 'doc'.
# ----> 6     doc=xml.dom.minidom.parse("employee.xml");
#       8     #In ra In ra tên của node gốc và tag name của node đầu tiên  trong file .xml
#       9     print(doc.nodeName)
#
# File c:\Users\Ngoc Toan\AppData\Local\Programs\Python\Python313\Lib\xml\dom\minidom.py:2006, in parse(file, parser, bufsize)
#    2004 if parser is None and not bufsize:
#    2005     from xml.dom import expatbuilder
# -> 2006     return expatbuilder.parse(file)
#    2007 else:
#    2008     from xml.dom import pulldom
#
# File c:\Users\Ngoc Toan\AppData\Local\Programs\Python\Python313\Lib\xml\dom\expatbuilder.py:907, in parse(file, namespaces)
#     904     builder = ExpatBuilder()
#     906 if isinstance(file, str):
# --> 907     with open(file, 'rb') as fp:
#     908         result = builder.parseFile(fp)
#     909 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'employee.xml'
