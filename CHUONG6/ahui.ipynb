# %%
#B) Đọc file bằng threading.Thread

import threading

import time

import pandas as pd

results = []

def load_csv_thread(filename):

time.sleep(0.2)

df pd.read_csv(filename)

esults.append((filename, len (df)))

print (f"Đọc xong (filename): (len(df))

dòng")

def read file multithread():

start = time.time()

threads = []

#Khởi tạo danh sách các luồng ban đầu trống.

for f in files:

t-threading.Thread(target-load_csv_thread, args=(f,)) #Tạo luồng th

threads.append(t)

t.start()

fort in threads:

t.join()

end time.time()

I

print (f"Thời gian đọc đa luồng: (end start:.4f) giây")
# Out:
#   Cell In[1], line 13
#     time.sleep(0.2)
#     ^
# IndentationError: expected an indented block after function definition on line 11

# %%
import threading

# global variable x
x = 0

# Viết hàm increment(), tăng giá trị biến toàn cục x
def increment():
    global x
    x += 1

# Hàm thread_task() thực hiện tác vụ luồng, thực hiện gọi hàm increment() 100000 lần.
def thread_task():
    for _ in range(100000):
        increment()

# Hàm main_task() thực hiện nhiệm vụ chính của chương trình:
# - Đặt giá trị của biến toàn cục x = 0
# - Tạo hai luồng (t1 và t2) để thực thi công việc trong thread_task()
def main_task():
    global x
    x = 0

    # creating threads
    t1 = threading.Thread(target=thread_task)
    t2 = threading.Thread(target=thread_task)

    # start threads
    t1.start()
    t2.start()

    # wait until threads finish their job
    t1.join()
    t2.join()

# Chương trình chạy vòng lặp 10 lần.
# Trong mỗi lần lặp gọi main_task() để thực hiện công việc.
# Sau đó in giá trị x ở mỗi lần lặp ra màn hình.
for i in range(10):
    main_task()
    print("Lần lặp {0}: x = {1}".format(i, x))
# Out:
# Lần lặp 0: x = 200000
# Lần lặp 1: x = 200000
# Lần lặp 2: x = 200000
# Lần lặp 3: x = 200000
# Lần lặp 4: x = 200000
# Lần lặp 5: x = 200000
# Lần lặp 6: x = 200000
# Lần lặp 7: x = 200000
# Lần lặp 8: x = 200000
# Lần lặp 9: x = 200000
