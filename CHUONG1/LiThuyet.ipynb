# %% [markdown]
# vidu1.2.1.1a

# %%
class Nhan_vien:
    id = 10
    name = "Nguyễn Văn A"
    age = 28
    def display (self):
        print(self.id, self.name, self.age)
nv1 = Nhan_vien()
nv1.display()
# Out:
# 10 Nguyễn Văn A 28

# %% [markdown]
# 1.2.1.1a

# %%
class NhanVien:
    """Đại diện cho một nhân viên với các thông tin cơ bản."""
    def __init__(self, id:int, name:str, age:int):
        """
        Khởi tạo một đối tượng NhanVien mới.
        Tham số:
        id (int): Mã số nhân viên.
        name (str): Tên của nhân viên.
        age (int): Tuổi của nhân viên.
        """
        self.id = id
        self.name = name
        self.age = age
    def display(self):
        """In ra thông tin chi tiết của nhân viên."""
        print(f"ID: {self.id}, Họ tên: {self.name}, Tuổi: {self.age}")
# Ứng dụng
#Tạo một đối tượng thuộc lớp NhanVien và gán giá trị ngay khi khởi tạo
nv1 = NhanVien(10, "Nguyễn Văn A", 28)
nv1.display()
# Out:
# ID: 10, Họ tên: Nguyễn Văn A, Tuổi: 28

# %% [markdown]
# tham số self 1.2.1.1b

# %%
class Myclass:
    def __init__(self,value):
        self.value=value
    def my_method(self):
        print('Giá trị của đối tượng :',self.value)
    #Tạo một đối tượng từ lớp Myclass
obj = Myclass(50) #Khai báo và khởi tạo đối tượng obj từ lớp Myclass
#Gọi phương thức my_method() của đối tượng obj
obj.my_method()
# Out:
# Giá trị của đối tượng : 50

# %% [markdown]
# ví dụ 1.2.1.2

# %%
class Dog:
    DogCount = 0 # Thuộc tính của lớp
#hàm khởi tạo đối tượng
    def __init__(self, name, size, age, color):
        self.name = name # Thuộc tính của đối tượng
        self.size = size # Thuộc tính của đối tượng
        self.age = age # Thuộc tính của đối tượng
        self.color = color # Thuộc tính của đối tượng
    def Go(self):
        print("I'm going...")
    def Stay(self, place):
        print("I'm staying at {}".format(place))
    def Lie(self, place):
        print("I'm lying at {}".format(place))
    def Bark(self): print("Whoop...")
    def Eat(self, food):
        print("I'm eating {}".format(food))
# khởi tạo đối tượng
bull = Dog("Bull", "large", 2, "Yellow");
bull.Stay("garden")
bull.Bark()
# Out:
# I'm staying at garden
# Whoop...

# %% [markdown]
# Ví dụ 1.2.1.3  contructor ko tham số

# %%
class Dog:
    #contructor ko tham số
    def __init__(self):
        print("đây là contructor ko tham số")
    def display(sefl,name):
        print("hello",name)
bull=Dog()
bull.display("the Dom")
# Out:
# đây là contructor ko tham số
# hello the Dom

# %% [markdown]
# Ví dụ 1.2.1.4. constructor có tham số.

# %%
#constructor có tham số
class Dog:
    #Constructor có tham số
    def __init__(self, name):
        print('Đây là constructor có tham số.')
        self.name=name
    def display(self):
        print("Hello",self.name)
bull = Dog("The Dom")
bull.display()
# Out:
# Đây là constructor có tham số.
# Hello The Dom

# %%
#constructor có tham số
class Dog:
#Constructor có tham số
    def __init__(self, name):
        print('Đây là constructor có tham số.')
        self.name=name
    def display(self):
        print("Hello",self.name)
bull = Dog("The Dom")
bull.display()
# Out:
# Đây là constructor có tham số.
# Hello The Dom

# %%
class Dog:
    def __init__(self, name, size, age, color):
        self.name=name# Thuộc tính của đối tượng
        self.size=size# Thuộc tính của đối tượng
        self.age=age# Thuộc tính của đối tượng
        self.color=color# Thuộc tính của đối tượng
    def Go(self):
        print("I'm going...")
    def Stay(self, place):
        print("I'm staying at {}".format(place))
    def Lie(self, place):
        print("I'm lying at {}".format(place))
    def Bark(self): print("Whoop...")
    def Eat(self, food):
        print("I'm eating {}".format(food))
bull = Dog("Dom", "large", "2", "Yellow");
# in thuộc tính đối tượng buj
print(getattr(bull,"age"))
# gán giá trị cuaer age cho 3
setattr(bull,"age",3)
# in giá trị của age
print(getattr(bull, 'age'))
# true nếu bull chứa thuộc tính large
print(hasattr(bull, 'large'))
# xóa thuộc tính age
delattr(bull, 'age')
# Kích hoạt lỗi nếu age đã bị xóa
# Out:
# 2
# 3
# False

# %%
class Dog:
# Class attributes
    DogCount = 0
    def __init__(self, name, size, age, color):
        self.name = name # object attributes
        self.size = size # object attributes
        self.age = age # object attributes
        self.color = color # object attributes
    # tạo đối tượng của lớp Dog
    bull = Dog("Dom", "large", 2, "yellow")
    # in thuộc tính name của đối tượng bull
    print(getattr(bull, 'name'))
    # gán giá trị của age cho 3
    setattr(bull, "age", 3)
    # in giá trị của age
    print(getattr(bull, 'age'))
    # true nếu bull chứa thuộc tính large
    print(hasattr(bull, 'size'))
    # xóa thuộc tính age
    delattr(bull, 'age')
    # Kích hoạt lỗi nếu age đã bị xóa
# Out:
# Dom
# 3
# True

# %% [markdown]
# vd3

# %%
class Dog:
    "vd minh hoaj"
    def __init__(self, name, size, age, color):
        self.name = name # object attributes
        self.size = size # object attributes
        self.age = age # object attributes
        self.color = color # object attributes
    def display_details(self):
        print("name:%s, size:%s, age:%d, color:%s" % (self.name,self.size,self.color,self.age))
bull = Dog("Dom", "large", 2, "yelow")
print(bull.__doc__)
print(bull.__dict__)
print(bull.__module__)
print(Dog.__name__)
# Out:
# vd minh hoaj
# {'name': 'Dom', 'size': 'large', 'age': 2, 'color': 'yelow'}
# __main__
# Dog

# %% [markdown]
# chỗ để minhnh họa cách sử dụng thuộc tính lớp (class attribute) và phương thức lớp (class
# method) để theo dõi số lượng đối tượng được tạo từ một lớp

# %%
class Dog:
# Thuộc tính lớp
    DogCount = 0
    def __init__(self, name, size, age, color):
        self.name = name # Thuộc tính đối tượng
        self.size = size #
        self.age = age #
        self.color = color #
    @classmethod
    def CreateDog(cls, name, size, age, color):
        cls.DogCount = cls.DogCount + 1
        return cls(name, size, age, color)
    @classmethod
    def get_dog_count(cls):
        return cls.DogCount
obj = Dog.CreateDog("bull", "large", 2, "yellow")
print("Số lượng đối tượng Dog đã được tạo:",
Dog.get_dog_count())
obj2 = Dog.CreateDog("poodle", "small", 1, "white")
print("Số lượng đối tượng Dog đã được tạo:",
Dog.get_dog_count())
# Out:
# Số lượng đối tượng Dog đã được tạo: 1
# Số lượng đối tượng Dog đã được tạo: 2

# %% [markdown]
# phương thức tĩnh

# %%
class Dog:
    DogCount = 0 # Thuộc tính lớp
    def __init__(self, name, size, age, color):
        self.name = name # Thuộc tính đối tượng
        self.size = size #
        self.color = color #
        Dog.DogCount += 1 #
    @staticmethod
    def Report():
        print("Tổng số đối tượng Dog:{}".format(Dog.DogCount))
# Tạo các đối tượng Dog
dog1 = Dog("Buddy", "Medium", 5, "Brown")
dog2 = Dog("Max", "Small", 3, "Black")
# Sử dụng phương thức tĩnh Report() để lấy số lượng đối tượng đã được tạo
dog1.Report()
# Out:
# Tổng số đối tượng Dog:2

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ____________tiết 2____________________

# %% [markdown]
# 1.2.1.11abc x

# %%
class Dog:
    DogCount = 0 # Thuộc tính lớp
    def __init__(self, name, size, age, color):
        self.name = name # Thuộc tính đối tượng
        self.size = size #
        self.color = color #
        Dog.DogCount += 1 #
        
#Instance method: Phương thức đối tượng sang sulf)
def show_count_instance(self):
    print (f"số lượng đối tượng Dog đã được tạo [instance method]= {Dog.DogCount}")
    
#Class method: Phương thức lớp (dùng cls)
@classmethod
def show_count_class(cls):
    print("Số lượng đối tượng Dog đã được tạo [class method)={cls.DogCount}")

#Static method: Phương thức tĩnh (không dùng self hay cls)
@staticmethod
def show_count_static():
    print (f"Số lượng đối tượng Dog đã được tạo [static method={Dog.DogCount}")

# %%
# Tạo các đối tượng Dog
dog1=Dog("Buddy", "Medium", 5, "Brown")
dog2=Dog("Max", "Small", 3, "Black")

#Gọi các phương thức để hiển thị số lượng đối tượng đã được tạo
dog1.show_count_instance() # Gọi đến phương thức đối tượng (instance method) (self) Gọi phương thức lớp qua tên lớp (gọi đến phương thức lớp)
dog1.show_count_class()
dog1.show_count_static() #Gọi phương thức tình tường mình qua tên lớp (không cần instance)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 4
#       1 dog1 = Dog("Buddy", "Medium", 5, "Brown")
#       2 dog2 = Dog("Max", "Small", 3, "Black")
# ----> 4 dog1.show_count_instance()
#       5 Dog.show_count_class()
#       6 Dog.show_count_static()
#
# AttributeError: 'Dog' object has no attribute 'show_count_instance'

# %%
class Dog:
    """Đại diện cho một con chó với các thuộc tính cơ bản."""
    # Thuộc tính lớp
    DogCount = 0
    species = 'Dog'

    # instance attribute
    def __init__(self, name, size, age, color):
        """
        Khởi tạo một đối tượng Dog mới.
        Tham số:
            name (str): Tên của con chó.
            size (str): Kích thước của con chó (ví dụ: 'Small', 'Medium', 'Large').
            age (int): Tuổi của con chó.
            color (str): Màu sắc của con chó.
        """
        self.name = name   # Thuộc tính đối tượng
        self.size = size
        self.age = age
        self.color = color


#instance của lớp Dog
obj1 = Dog("Buddy", "Medium", 5, "Brown")
obj2 = Dog("Max", "Small", 3, "Black")
#Truy cập thuộc tính lớp
print("obj1 is a {}".format(obj1.__class__.species))
print("obj2 is also a {}".format(obj2.__class__.species))
#Truy cập thuộc tính của instance
print("{} is {} years old".format(obj1.name, obj1.age))
print("{} is {} years old".format(obj2.name, obj2.age))
# Out:
# obj1 is a Dog
# obj2 is also a Dog
# Buddy is 5 years old
# Max is 3 years old

# %% [markdown]
# a

# %% [markdown]
# b

# %%
class Dog:
    """
    Minh họa lớp Dog với các thuộc tính protected
    """
    _DogCount = 0   # protected: thuộc tính LỚP (giao diện protected)

    def __init__(self, name: str, size: str, age: int):
        self._name = name    # protected: thuộc tính protected (theo quy ước)
        Dog._DogCount += 1   # tăng thuộc tính lớp

    def _display(self):  # Phương thức protected
        print(f"Name is {self._name}")

# %% [markdown]
# 1.3.1.1c

# %%
class Dog:
    _DogCount = 0  

    def __init__(self, name: str, size: str, age: int):
        self.__name = name    # protected: thuộc tính protected (theo quy ước)
        self.__age=age
        Dog._DogCount += 1   # tăng thuộc tính lớp

    def _display(self):  # Phương thức private
        print(f"Name: {self.__name}, age: {self.__age}")

# %% [markdown]
# mangling

# %%
class Dog:
    _DogCount = 0  

    def __init__(self, name: str, size: str, age: int):
        self._name = name    # protected: thuộc tính protected (theo quy ước)
        self._age=age

# %% [markdown]
# 1.3.1.2 minh hoaj seter getter

# %%
class Dog:
    def __init__(self, name, size, age, color):
        self._name = name # Thuộc tính đối tượng
        self._size = size #
        self.__color = color #
        self.__age=age
        
        
@property # Định nghĩa phương thức getter cho thuộc tính prívate_age
def age(self):
    print("Getter for age called")
    if not hasattr(self, "_Dog_age"): # Kiểm tra xem age có tòn tại không
        raise AttributeError("Age has been deleted or not set")
    return self._age# Trả về giá trị tuổi (private)

@age.setter
def age(self, value): #Setter cho thuộc tính private_age
    print("Setter for age called")
    if value < 0:
        raise ValueError("Age cannot be negative")
    self. age=value # Cập nhật giá trị tuổi (private)
    
@age.deleter # Định nghĩa deleter cho thuộc tính private_age
def age(self):
    print("Deleter for age called")
    if not hasattr(self, "_Dog_age"): # Kiếm tra trước khi xóa
        raise AttributeError("Age has already been deleted or not set")
    del self._age # Xóa thuộc tính private_age

# %%
#Ví dụ ứng dụng
dog=Dog("Bull", "large", 2, "yellow")
#Truy cập như thuộc tính nhờ @property
print(f"Bull's age is {dog.age}") # Truy cập thông qua getter

# %% [markdown]
# 1.3.2.1 minh họa kế thừa

# %%
class Animal:
    """ Lớp cơ sở (lớp cha)"""
    def _init_(self, name):
        self._name=name
        
    def Display(self):# hiển thị tên con vật
        print("I'm {}".format(self._name))
        
class Dog (Animal):
    """Lớp dẫn xuất (lớp con)"""
    def __init__(self, name, size, age, color): # Khởi tạo lớp con
        super()._init__(name) # Gọi hàm khởi tạo của lớp cha
        self.size=size
        self.age = age
        self.color = color
        
    def Go(self, place):# Phương thức riêng của lớp con
        print("I'm going to {}".format(place))

# %%
 #Ứng dụng đơn kế thừa
obj1 = Dog("Bull", "large", 2, "yellow")
obj1.Display() # Gọi phương thức kế thừa từ lớp cha
obj1.Go("garden") # Gọi phương thức riêng của lớp con
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 2
#       1  #Ứng dụng đơn kế thừa
# ----> 2 obj1 = Dog("Bull", "large", 2, "yellow")
#       3 obj1.Display() # Gọi phương thức kế thừa từ lớp cha
#       4 obj1.Go("garden") # Gọi phương thức riêng của lớp con
#
# Cell In[65], line 10, in Dog.__init__(self, name, size, age, color)
#       9 def __init__(self, name, size, age, color): # Khởi tạo lớp con
# ---> 10     super()._init__(name) # Gọi hàm khởi tạo của lớp cha
#      11     self.size=size
#      12     self.age = age
#
# AttributeError: 'super' object has no attribute '_init__'

# %% [markdown]
# đa kế thửa

# %%
class Zebra: #lớp cha 1
    def __init__ (self):
        print ("Zebra")
    def Display(self):
        print("I'm a zebra")
class Donkey:#Lớp cha2
    def __init__(self):
        print("Donkey")
    def Display(self):
        print("I'm a donkey")
class Zonkey (Zebra, Donkey): #Lớp con Zonkey kẻ thừa lớp chal, chaz
    def __init__(self):
        Zebra.__init__(self)
        Donkey.__init__(self)
        print("Zonkey")
obj=Zonkey()
obj.Display() # có vấn đề phát sinh khi chạy phương thức này!
# Out:
# Zebra
# Donkey
# Zonkey
# I'm a zebra

# %% [markdown]
# vd 1.3.2.3 đa kế thừa con ông cháu cha

# %%
class LopCha:
    def __init__(self, ten_cha):
        self.ten_cha = ten_cha

    def thong_tin(self):
        print("Tôi là Lớp Cha, tên của tôi là", self.ten_cha)


class LopCon(LopCha):
    def __init__(self, ten_cha, ten_con):
        # Gọi hàm khởi tạo của lớp cha để khởi tạo các thuộc tính từ lớp cha
        super().__init__(ten_cha)
        self.ten_con = ten_con

    def thong_tin(self):
        print("Tôi là Lớp Con, tên của tôi là", self.ten_con)
        # Gọi phương thức của lớp cha bằng cách sử dụng super()
        super().thong_tin()


class LopChau(LopCon):
    def __init__(self, ten_cha, ten_con, ten_chau):
        # Gọi hàm khởi tạo của LopCha và LopCon để khởi tạo các thuộc tính
        # LớpChau kế thừa LopCon
        super().__init__(ten_cha, ten_con)
        self.ten_chau = ten_chau

    def thong_tin(self):
        print("Tôi là Lớp Cháu, tên của tôi là", self.ten_chau)
        # Gọi phương thức của LopCon
        super().thong_tin()


# Sử dụng các lớp
lop_chau = LopChau("Ông A", "Bác B", "Cháu C")
lop_chau.thong_tin()
# Out:
# Tôi là Lớp Cháu, tên của tôi là Cháu C
# Tôi là Lớp Con, tên của tôi là Bác B
# Tôi là Lớp Cha, tên của tôi là Ông A

# %% [markdown]
# 1.3.3.1

# %%
from abc import ABC, abstractmethod

#Tạo lớp trừu tượng "Animal" với phương thức trừu tượng "Say
class Animal (ABC):
    def Say(self):
        pass
    
#Tạo lớp con 'Dog' kế thừa từ Animal'
class Dog (Animal):
    def Say(self):
        print("Whoooopp whoooppp...")
#Tạo lớp con 'Cat' kế thừa từ Animal
class Cat(Animal):
    def Say(self):
        print("Meooo meooo")
#Định nghĩa một phương thức "Jump' cho lớp 'Cat'
def Jump(self):
    print("I'm jumping up high")
#Khởi tạo đối tượng từ lớp 'Dog'
obj_dog=Dog()
#Gọi phương thức 'Say' của đối tượng 'obj_dog
obj_dog.Say()
#Khởi tạo đối tượng từ lớp 'Cat'
obj_cat=Cat()
#691 phương thức 'Say' của đối tượng 'obj_cat'
obj_cat.Say()
# Out:
# Whoooopp whoooppp...
# Meooo meooo

# %% [markdown]
# c
